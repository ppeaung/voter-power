# %%
import IPython
import os
import csv 
import geopandas as gpd
import matplotlib.pyplot as plt
import networkx as nx
import pandas as pd
import numpy as np
from scipy.stats import t
from shapely import wkt

# ======================================================================
# Constants
# ======================================================================

YEAR = 2024
SIGMA = 5
"""
state_fips = {
    'AL': 1, 'AK': 2, 'AZ': 4, 'AR': 5, 'CA': 6,
    'CO': 8, 'CT': 9, 'DE': 10, 'FL': 12, 'GA': 13,
    'HI': 15, 'ID': 16, 'IL': 17, 'IN': 18, 'IA': 19,
    'KS': 20, 'KY': 21, 'LA': 22, 'ME': 23, 'MD': 24,
    'MA': 25, 'MI': 26, 'MN': 27, 'MS': 28, 'MO': 29,
    'MT': 30, 'NE': 31, 'NV': 32, 'NH': 33, 'NJ': 34,
    'NM': 35, 'NY': 36, 'NC': 37, 'ND': 38, 'OH': 39,
    'OK': 40, 'OR': 41, 'PA': 42, 'RI': 44, 'SC': 45,
    'SD': 46, 'TN': 47, 'TX': 48, 'UT': 49, 'VT': 50,
    'VA': 51, 'WA': 53, 'WV': 54, 'WI': 55, 'WY': 56,
    'DC': 11
}
"""

state_fips = {
    'MT': 4
}
# ======================================================================
# Helper Functions
# ======================================================================

def round_to_nearest_tens(x):
    return round(x / 10) * 10

# ======================================================================
# Meta-Margin Calculation 
# ======================================================================

# TODO: Implement

# ======================================================================
# Reading Shapefiles
# ======================================================================

df_all = pd.DataFrame()

for index, state_abbreviation in enumerate(state_fips):
    # Read shapefile information
    shape_file = gpd.read_file(f'../data/state_senate/district-shapes-{state_abbreviation}-ss/POLYGON.shp')
    shape_file['id'] = shape_file['id'].astype(int)
    shape_file = shape_file.rename(columns = {'id': 'NAMELSAD'})
    shape_file['NAMELSAD'] = shape_file['NAMELSAD'].apply(lambda x: f'Congressional District {x}')
    
    # Read election data & calculate margins
    csv_path = f'../data/state_senate/district-data-{state_abbreviation}-ss/district-data.csv'

    df = pd.read_csv(csv_path)
    df = df[['ID', 'E_20_PRES_Total', 'E_20_PRES_Dem', 'E_20_PRES_Rep']]
    df = df.drop(index=0)
    df['Margins'] = (df['E_20_PRES_Dem'] - df['E_20_PRES_Rep']) / df['E_20_PRES_Total']
    df = df.rename(columns = {'ID': 'NAMELSAD'})
    
    # Voter Power Calculation
    # t-pdf setup 
    deg_f = 3 
    t_dist = t(deg_f)

    # For sanity checking
    # TODO: Ask about how meta margin changes for different elections... 
    metamargin = 0 

    Z = (df['Margins'] - metamargin) / SIGMA
    num = t_dist.pdf(Z)
    den = df['E_20_PRES_Total']

    df['Voter Power'] = np.divide(num, den)

    # Renaming variables and adding STATEFP
    df['NAMELSAD'] = df['NAMELSAD'].apply(lambda x: f'Congressional District {x}')
    df["STATEFP"] = state_fips[state_abbreviation]

    # Merging data
    df = pd.merge(df, shape_file[['NAMELSAD', 'geometry']], on = 'NAMELSAD')
    
    if index == 0:
        df_all = pd.concat([df_all, df[['NAMELSAD', 'Margins', 'STATEFP', 'Voter Power', 'geometry']]], ignore_index=True)
    else: 
        df_all = pd.concat([df_all[['NAMELSAD', 'Margins', 'STATEFP', 'Voter Power', 'geometry']], df[['NAMELSAD', 'Margins', 'STATEFP', 'Voter Power', 'geometry']]], axis=0)
        
    print(df_all.head())
    
# Normalize Voter Power
df_all['Voter Power'] = ((df_all['Voter Power']  - df_all['Voter Power'].min()) / (df_all['Voter Power'].max() - df_all['Voter Power'].min()))*100
df_all['Voter Power'] = df_all['Voter Power'].apply(round_to_nearest_tens)
print(df_all)

# Save Data 
dir_path = os.path.dirname(os.path.realpath("__file__"))
path = os.path.join(dir_path, f'../outputs/{YEAR}.stateSenate.VoterPower.csv')
df_all.to_csv(path, index=False, float_format='%.2f')
# Out:
#                    NAMELSAD   Margins  STATEFP  Voter Power  \
# 0  Congressional District 1 -0.507837        4     0.000028
# 1  Congressional District 2  0.023962        4     0.000028
# 2  Congressional District 3 -0.382841        4     0.000028
# 3  Congressional District 4 -0.299427        4     0.000036
# 4  Congressional District 5 -0.413603        4     0.000030
#
#                                             geometry
# 0  POLYGON ((-114.61912 48.74556, -114.61906 48.7...
# 1  POLYGON ((-114.20977 48.35717, -114.20836 48.3...
# 2  POLYGON ((-114.20977 48.35717, -114.21152 48.3...
# 3  POLYGON ((-114.33065 48.18903, -114.33063 48.1...
# 4  POLYGON ((-114.36810 47.96203, -114.36740 47.9...
#                      NAMELSAD   Margins  STATEFP  Voter Power  \
# 0    Congressional District 1 -0.507837        4           10
# 1    Congressional District 2  0.023962        4           10
# 2    Congressional District 3 -0.382841        4           10
# 3    Congressional District 4 -0.299427        4           40
# 4    Congressional District 5 -0.413603        4           20
# 5    Congressional District 6 -0.388797        4           10
# 6    Congressional District 7 -0.361549        4           20
# 7    Congressional District 8  0.196254        4           60
# 8    Congressional District 9 -0.469414        4           20
# 9   Congressional District 10 -0.079960        4           50
# 10  Congressional District 11 -0.132453        4           60
# 11  Congressional District 12 -0.163590        4           40
# 12  Congressional District 13 -0.401206        4           30
# 13  Congressional District 14 -0.359699        4           40
# 14  Congressional District 15 -0.584113        4           30
# 15  Congressional District 16  0.148046        4           90
# 16  Congressional District 17 -0.673135        4           20
# 17  Congressional District 18 -0.535652        4           30
# 18  Congressional District 19 -0.586917        4           20
# 19  Congressional District 20 -0.384152        4           40
# 20  Congressional District 21  0.039790        4          100
# 21  Congressional District 22 -0.291851        4           30
# 22  Congressional District 23  0.051327        4           40
# 23  Congressional District 24 -0.005684        4           70
# 24  Congressional District 25 -0.220629        4           30
# 25  Congressional District 26 -0.198641        4           20
# 26  Congressional District 27 -0.411850        4           30
# 27  Congressional District 28 -0.434017        4            0
# 28  Congressional District 29  0.032479        4            0
# 29  Congressional District 30  0.160271        4            0
# 30  Congressional District 31  0.244230        4           30
# 31  Congressional District 32  0.141678        4           20
# 32  Congressional District 33  0.155064        4           10
# 33  Congressional District 34 -0.297609        4           30
# 34  Congressional District 35 -0.399812        4           10
# 35  Congressional District 36  0.125092        4           40
# 36  Congressional District 37  0.158074        4           30
# 37  Congressional District 38 -0.373369        4           10
# 38  Congressional District 39 -0.526213        4           10
# 39  Congressional District 40  0.069339        4           10
# 40  Congressional District 41  0.063779        4           20
# 41  Congressional District 42 -0.131652        4           10
# 42  Congressional District 43 -0.349497        4            0
# 43  Congressional District 44 -0.376469        4            0
# 44  Congressional District 45 -0.164844        4           10
# 45  Congressional District 46  0.167076        4           20
# 46  Congressional District 47  0.236608        4           10
# 47  Congressional District 48  0.440512        4           10
# 48  Congressional District 49  0.186936        4           20
# 49  Congressional District 50  0.343517        4           20
#
#                                              geometry
# 0   POLYGON ((-114.61912 48.74556, -114.61906 48.7...
# 1   POLYGON ((-114.20977 48.35717, -114.20836 48.3...
# 2   POLYGON ((-114.20977 48.35717, -114.21152 48.3...
# 3   POLYGON ((-114.33065 48.18903, -114.33063 48.1...
# 4   POLYGON ((-114.36810 47.96203, -114.36740 47.9...
# 5   POLYGON ((-113.92978 47.90622, -113.92634 47.9...
# 6   POLYGON ((-114.35024 47.60193, -114.34956 47.5...
# 7   POLYGON ((-113.75347 47.93733, -113.75447 47.9...
# 8   POLYGON ((-112.79609 46.96253, -112.79593 46.9...
# 9   POLYGON ((-111.28170 47.51998, -111.29160 47.5...
# 10  POLYGON ((-111.24159 47.50169, -111.24161 47.5...
# 11  POLYGON ((-111.28429 47.47239, -111.27834 47.4...
# 12  POLYGON ((-111.26178 47.53304, -111.25747 47.5...
# 13  POLYGON ((-111.00624 48.99788, -111.06905 48.9...
# 14  POLYGON ((-104.04404 47.99608, -104.04406 47.9...
# 15  POLYGON ((-104.75786 48.25860, -104.75786 48.2...
# 16  POLYGON ((-105.49201 46.65677, -105.49206 46.6...
# 17  POLYGON ((-105.81985 46.36923, -105.81730 46.3...
# 18  POLYGON ((-108.82678 47.71120, -108.82873 47.7...
# 19  POLYGON ((-108.47476 45.76465, -108.47446 45.7...
# 20  POLYGON ((-106.72757 45.67647, -106.75064 45.6...
# 21  POLYGON ((-108.46619 45.84484, -108.46617 45.8...
# 22  POLYGON ((-108.56940 45.78405, -108.56679 45.7...
# 23  POLYGON ((-108.51499 45.75945, -108.51499 45.7...
# 24  POLYGON ((-108.57624 45.77617, -108.57894 45.7...
# 25  POLYGON ((-108.58695 45.77690, -108.58619 45.7...
# 26  POLYGON ((-108.80256 45.67946, -108.80256 45.6...
# 27  POLYGON ((-109.95848 46.00384, -109.95916 46.0...
# 28  POLYGON ((-110.78383 46.19270, -110.78776 46.1...
# 29  POLYGON ((-111.05456 44.99974, -111.05456 45.0...
# 30  POLYGON ((-111.07729 45.67840, -111.07755 45.6...
# 31  POLYGON ((-111.07647 45.68570, -111.07527 45.6...
# 32  POLYGON ((-111.04732 45.67119, -111.04669 45.6...
# 33  POLYGON ((-111.26578 45.80389, -111.26548 45.8...
# 34  POLYGON ((-112.07659 45.86756, -112.08721 45.8...
# 35  POLYGON ((-112.57711 46.17898, -112.57640 46.1...
# 36  POLYGON ((-112.53894 45.98323, -112.53338 45.9...
# 37  POLYGON ((-113.18662 46.16866, -113.18346 46.1...
# 38  POLYGON ((-111.27033 45.82279, -111.27219 45.8...
# 39  POLYGON ((-112.02809 46.60282, -112.02712 46.6...
# 40  POLYGON ((-112.03192 46.59808, -112.03774 46.5...
# 41  POLYGON ((-111.89404 46.64645, -111.89405 46.6...
# 42  POLYGON ((-114.41505 45.92232, -114.41485 45.9...
# 43  POLYGON ((-114.33085 46.57361, -114.33121 46.5...
# 44  POLYGON ((-115.06348 46.99316, -115.06114 46.9...
# 45  POLYGON ((-114.10044 47.32304, -114.09779 47.3...
# 46  POLYGON ((-113.89612 46.87367, -113.89721 46.8...
# 47  POLYGON ((-114.02814 46.86697, -114.02814 46.8...
# 48  POLYGON ((-114.03003 46.86694, -114.03162 46.8...
# 49  POLYGON ((-113.98381 46.87237, -113.98339 46.8...

# %%
csv_path = f'../outputs/{YEAR}.stateSenate.VoterPower.csv'
df = pd.read_csv(csv_path)

from shapely import wkt
df['geometry'] = df['geometry'].apply(wkt.loads)
gdf = gpd.GeoDataFrame(df, crs='epsg:4326')
gdf.plot("Margins")
# Out:
# <Axes: >
